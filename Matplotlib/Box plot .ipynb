# %% [markdown]
# from matplotlib import pyplot as plt
# import numpy as np

# %%
# Preparing data
a = [1,2,3,4,5,6,7,8,9]
b = np.random.randint(1,10,9) 
c = np.random.randint(1,10,9) 

data = list([a,b,c])

# %%
b
# Out:
# array([5, 6, 6, 6, 8, 1, 5, 4, 4])

# %%
c
# Out:
# array([4, 9, 9, 4, 7, 3, 4, 9, 5])

# %%
data
# Out:
# [[1, 2, 3, 4, 5, 6, 7, 8, 9],
#  array([5, 6, 6, 6, 8, 1, 5, 4, 4]),
#  array([4, 9, 9, 4, 7, 3, 4, 9, 5])]

# %%
plt.boxplot(data)
plt.show()

# %% [markdown]
# min =1 , median = 5 , max=9
# min = 1 , median = 5  , max = 8
# min =3 , median =5 , max =9

# %% [markdown]
# # Violin plot

# %%
plt.violinplot(data)
plt.show()
